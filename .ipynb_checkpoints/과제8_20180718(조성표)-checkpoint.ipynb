# %% [markdown]
# # 과제8 - 몽고DB에 화가 작품들 base64로 인코딩하여 저장
# ### 2018.07.20 고려대학교 조성표
# 위키미디어의 르누아르 페이지를 Regex를 사용해 크롤링했습니다. 모두 원본 크기로 저장했으며, 그림 데이터베이스는 170여개의 그림에 1.1GB의 용량을 지닙니다.

# %% [markdown]
# **In MongoDB, a database is not created until it gets content!**
#
# MongoDB waits until you have created a collection (table), with at least one document (record) before it actually creates the database (and collection).

# %%
def add_pic(title, encoded_pic, artist = 'August Renoir'):
    new_pic = {'artist': artist,
               'title': title,
               'base64_encoded': encoded_pic}
    db.Renoir.insert_one(new_pic)

# %%
import re
import base64
import pymongo
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient

# Create Database and Collection
client = MongoClient('localhost', 27017)
db = client['renoir_gallery']
db.get_collection('Renoir')

html = requests.get('https://commons.wikimedia.org/wiki/Category:Paintings_by_Pierre-Auguste_Renoir')
soup = BeautifulSoup(html.text, 'lxml')

title_list = [title.get_text().replace('.jpg', '') for title in soup.select('div.gallerytext a')]
image_list = [link.get('src') for link in soup.select('li.gallerybox img')]

img_dict = dict(zip(title_list, image_list))

# Delete Images which does not ends with .jpg
for key in list(img_dict):
    if '.' in key: del img_dict[key]

# Change urls of img_dict values to image links
img_dict = dict((k, re.findall('(^https.+jpg)/.+px?',v)[0].replace('thumb/', '')) for (k,v) in img_dict.items())

for img_title, img_url in img_dict.items():
    req = requests.get(img_url)
    encoded = base64.b64encode(req.content)
    
    add_pic(img_title, encoded)
    print('{} Successfully encoded!'.format(img_title))
# Out:
# 'Au Bord de l'Eau' by Pierre-Auguste Renoir, 1885 Successfully encoded!
# Cópia de Saules et personnages dans une barque Successfully encoded!
# Pierre-Auguste Renoir - Chestnut Tree in Bloom Successfully encoded!
# 1887, Renoir, River Landscape Successfully encoded!
# Pierre Auguste Renoir Noirmoutier Successfully encoded!
# Claude Terrasse, by Pierre-Auguste Renoir Successfully encoded!
# 1903 Renoir Blick aufs Meer Successfully encoded!
# A Road in Louveciennes MET DP265242 Successfully encoded!
# A Waitress at Duval's Restaurant MET DT1488 Successfully encoded!
# A Young Girl with Daisies MET DT2161 Successfully encoded!
# Auguste Renoir - Field of Banana Trees - Google Art Project Successfully encoded!
# Auguste Renoir - Maternity - Google Art Project Successfully encoded!
# Auguste Renoir - Pont Neuf, Paris - Google Art Project Successfully encoded!
# Auguste Renoir - Snow-covered Landscape - Google Art Project Successfully encoded!
# Auguste Renoir - The Mosque - Google Art Project Successfully encoded!
# Auguste Renoir - The Swing - Google Art Project Successfully encoded!
# Auguste Renoir - View of a Park - Google Art Project Successfully encoded!
# Auguste Renoir - Young Girls at the Piano - Google Art Project Successfully encoded!
# Auguste Renoir Le chapeau epingle Successfully encoded!
# Auguste Renoir, Versailles, 1900–1905 Successfully encoded!
# Brooklyn Museum - Landscape La Clairière - Pierre-Auguste Renoir Successfully encoded!
# Brooklyn Museum - The Vineyards at Cagnes (Les Vignes à Cagnes) - Pierre-Auguste Renoir Successfully encoded!
# By the Seashore MET DT1875 Successfully encoded!
# Campo de trigo Successfully encoded!
# Child with Toys - Gabrielle and the Artist's Son, Jean A34140 Successfully encoded!
# Dance-At-Bougival Successfully encoded!
# Eugène Murer (Hyacinthe-Eugène Meunier) Successfully encoded!
# Eugène Murer (Hyacinthe-Eugène Meunier, 1841–1906) MET DT1882 Successfully encoded!
# Figures on the Beach MET 2433 Successfully encoded!
# Figures on the Beach MET DT3128 Successfully encoded!
# Georges Rivière A12821 Successfully encoded!
# Hills around the Bay of Moulin Huet, Guernsey MET DT1880 Successfully encoded!
# I nærheden af Cagnes Successfully encoded!
# Impressionist Windows - panoramio Successfully encoded!
# In the Meadow MET DT1398 Successfully encoded!
# Iris Ideal Renoir Successfully encoded!
# Jeanne Samary E-001663-20120504 Successfully encoded!
# La Seine à Argenteuil par Auguste Renoir Successfully encoded!
# Landscape at Vétheuil G-001657-20120817 Successfully encoded!
# Landscape between Storms G-001650-20120801 Successfully encoded!
# Landscape with two people Successfully encoded!
# Lithographie Renoir Successfully encoded!
# Madame Georges Charpentier (Marguérite-Louise Lemonnier, 1848–1904) and Her Children, Georgette-Berthe (1872–1945) and Paul-Émile-Charles (1875–1895) MET DT49 Successfully encoded!
# Madame Édouard Bernier (Marie-Octavie-Stéphanie Laurens, 1838–1920) MET DT1399 Successfully encoded!
# Mademoiselle Amélie Diéterle par Auguste Renoir (B) Successfully encoded!
# Mademoiselle Amélie Diéterle par Auguste Renoir en 1903 (A) Successfully encoded!
# Marie Murer A13408 Successfully encoded!
# Medlar Trees, Cagnes Successfully encoded!
# Mlle Charlotte Berthier A27876 Successfully encoded!
# Mosque at Algiers, Renoir, 1882 Successfully encoded!
# Mujer con sombrilla en un jardín Successfully encoded!
# Nini in the Garden (Nini Lopez) MET DT1874 Successfully encoded!
# Pierre Auguste Renoir - Mädchenbildnis (Elisabeth Maître), 1897 Successfully encoded!
# Pierre Auguste Renoir - Rozen - 0431 - Rijksmuseum Twenthe Successfully encoded!
# Pierre Auguste Renoir - The Bathers - Google Art Project Successfully encoded!
# Pierre-Auguste Renoir (Musée des Beaux-arts de Lyon) (10852663114) Successfully encoded!
# Pierre-Auguste Renoir - A Woman Nursing a Child - Google Art Project Successfully encoded!
# Pierre-Auguste Renoir - Acrobats at the Cirque Fernando (Francisca and Angelina Wartenberg) - Google Art Project Successfully encoded!
# Pierre-Auguste Renoir - After the Bath (Après le bain) - BF225 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - After the Bath (La Sortie du bain) - BF142 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Algerian Girl - Google Art Project Successfully encoded!
# Pierre-Auguste Renoir - Andrée in a Hat, Reading (Andrée en chapeau, lisant) - BF932 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Andrée in Pink, Reclining (Andrée en rose étendue) - BF921 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Anemones (Anémones) - BF1167 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Anemones (Anémones) - BF531 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Apple and Pear (Pomme et poire) - BF243 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Apple Vendor (La Marchande de pommes) - BF8 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Apples (Pommes) - BF52 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Apples (Pommes) - BF55 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Apples and Lemons on a Cloth (Pommes et citrons sur une nappe) - BF27 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Apples, Orange, and Lemon (Pommes, oranges et citrons) - BF17 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Autumn Landscape (Paysage d'automne) - BF933 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Baby's Head (Tête d'enfant, profil à gauche) - BF76 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bateau-lavoir sur la Seine Successfully encoded!
# Pierre-Auguste Renoir - Bather (Baigneuse) - BF228 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bather (Baigneuse) - BF301 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bather (Baigneuse) - BF71 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bather and Maid (La Toilette de la baigneuse) - BF899 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bather Drying Herself (Baigneuse s'essuyant) - BF28 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bather Drying Herself (Baigneuse s'essuyant) - BF68 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bather Gazing at Herself in the Water (Baigneuse se mirant dans l'eau) - BF217 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bather in Three-Quarter View (Baigneuse vue de trois quarts) - BF284 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bathers (Baigneuses) - BF945 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bathing Group - BF709 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Before the Bath (Avant le bain) - BF9 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bois de la Chaise (Noirmoutier) - BF163 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bords de mer Successfully encoded!
# Pierre-Auguste Renoir - Bouquet - BF838 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bouquet of Roses (Bouquet de roses) - BF33 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bouquet of Roses (Le Bouquet de roses) - BF538 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bowl, Figs, and Apples (Écuelle, figues et pommes) - BF102 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bust of a Woman (Buste de femme) - BF31 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Bust of Woman in Red (Buste de femme en rouge) - BF60 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Caryatids (Cariatides), also called Deux baigneuses (panneau décoratif) - BF918 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Caryatids (Cariatides), also called Deux baigneuses (panneau décoratif) - BF919 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Champ de bananiers Successfully encoded!
# Pierre-Auguste Renoir - Chestnut Trees, Pont-Aven (Châtaigniers, Pont-Aven) - BF242 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Child Reading (Enfant lisant) - BF51 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Children on the Seashore, Guernsey (Enfants au bord de la mer à Guernesey) - BF10 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Claude Renoir - BF935 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Composition, Five Bathers (Composition, cinq baigneuses) - BF902 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Cup of Chocolate (La Tasse de chocolat) - BF40 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Dovecote at Bellevue (Pigeonnier de Bellevue) - BF969 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Embroiderers (Les Brodeuses) - BF239 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Environs of Berneval - BF6 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Environs of Briey (Environs de Briey) - BF151 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Farmhouse (La Ferme) - BF47 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Femme avec parasol dans un jardin - Google Art Project Successfully encoded!
# Pierre-Auguste Renoir - Femme à l'ombrelle Successfully encoded!
# Pierre-auguste renoir - fillette lisant Successfully encoded!
# Pierre-Auguste Renoir - Flowers (Fleurs) - BF532 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Flowers in a Green Vase (Fleurs dans un vase vert) - BF991 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Fruit and Bonbonnière - BF39 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girl at the Foot of a Tree (Fillette au pied d'un arbre) - BF255 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girl Darning (Femme reprisant) - BF114 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girl in Gray-Blue - BF222 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girl on a Balcony, Cagnes (Jeune femme au balcon, Cagnes) - BF98 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girl Seated in a Landscape (Jeune fille assise dans un jardin) - BF11 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girl with a Jump Rope (Portrait of Delphine Legrand) - BF137 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girl with Basket of Fish (Pêcheuse de poissons) - BF53 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girl with Basket of Oranges (Marchande d'oranges) - BF65 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girl with Pink Bonnet (Jeune fille au chapeau rose) - BF118 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girls in a Landscape (Jeunes filles dans un paysage) - BF931 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girls in the Grass Arranging a Bouquet (Fillette couchée sur l'herbe et jeune fille arrangeant un bouquet) - BF155 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Girls with Hats (Jeunes filles aux chapeaux) - BF130 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Glade (Clairière) - BF26 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Grape Gatherers (Vendangeuses) - BF937 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Head (Tête), also called Etude de brodeuse - BF553 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Head of Young Girl (Tête de jeune fille) - BF1000 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Head of Young Girl (Tête de jeune fille) - BF46 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Henriot Family (La Famille Henriot) - BF949 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Houses in a Park (Maisons dans un parc) - BF67 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Houses on a Hill (Groupe de maisons sur un coteau) - BF146 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - In Brittany (En Bretagne) - BF161 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - In the Woods - Google Art Project Successfully encoded!
# Pierre-Auguste Renoir - Jardin de la rue Cortot Successfully encoded!
# Pierre-Auguste Renoir - Jardin à Fontenay Successfully encoded!
# Pierre-Auguste Renoir - Jeune femme en buste - circa 1900 - 001 Successfully encoded!
# Pierre-Auguste Renoir - La Moisson Successfully encoded!
# Pierre-Auguste Renoir - La Place Clichy Successfully encoded!
# Pierre-Auguste Renoir - La Seine à Chatou Successfully encoded!
# Pierre-Auguste Renoir - Landscape (Paysage) - BF1061 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape (Paysage) - BF236 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape (Paysage) - BF4 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape (Paysage) - BF43 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape (Paysage) - BF536 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape (Paysage) - BF537 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape (Paysage) - BF74 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape (Paysage) - BF818 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape (Paysage) - BF948 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape - BF542 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape with Woman and Dog (Femme et chien dans un paysage) - BF541 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape with Woman Gardening (Paysage et femme jardinant) - BF884 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape with Woman in Pink and White (Paysage avec femme en rose et blanc) - BF922 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Landscape, La Gaude (Paysage, La Gaude) - BF19 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Le Béal - BF859 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Le Cannet - BF245 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Leaving the Conservatory (La Sortie du conservatoire) - BF862 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Lemons and Orange (Citrons et orange) - BF974 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Les oliviers de Cagnes - 1909 - 001 Successfully encoded!
# Pierre-Auguste Renoir - Lise in a Straw Hat (Jeune fille au chapeau de paille) - BF874 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Louveciennes - BF860 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Luncheon (Le Déjeuner) - BF45 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Meadow (La Prairie) - BF221 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Montagne Sainte-Victoire (Paysage) - BF288 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Mother nursing her child Successfully encoded!
# Pierre-Auguste Renoir - Mussel-Fishers at Berneval (Pêcheuses de moules à Berneval, côte normand) - BF989 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Nude from the Back (Nu de dos) - BF976 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Nude Study, Bust of a Woman (Étude de nu, buste de femme) - BF157 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Nude Torso of Young Girl (Torse nu de jeune fille) - BF54 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Nude with Castanets - BF147 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Nude Woman Reclining (Femme nue couchée sur le dos) - BF1142 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Oranges and Bananas (Oranges et bananes) - BF2 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Oranges, Bananas, and Teacup (Oranges, bananes et tasse de thé) - BF61 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Paisaje de L'Ile de France Successfully encoded!
# Pierre-Auguste Renoir - Paysage Successfully encoded!
# Pierre-Auguste Renoir - Pears (Poires) - BF49 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Peninsula of Saint-Jean (Presqu'île de Saint-Jean) - BF240 - Barnes Foundation Successfully encoded!
# Pierre-Auguste Renoir - Picnic (Le Déjeuner sur l'herbe) - BF567 - Barnes Foundation Successfully encoded!
